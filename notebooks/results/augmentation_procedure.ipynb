# %%
import pandas as pd
import seaborn as sns
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
sns.set_theme(rc={"figure.dpi": 100}) # Set DPI to 300 for high resolution

# %%
sns.set_theme(style="whitegrid")
sns.color_palette("bright")
# Out:
# [(0.00784313725490196, 0.24313725490196078, 1.0),
#  (1.0, 0.48627450980392156, 0.0),
#  (0.10196078431372549, 0.788235294117647, 0.2196078431372549),
#  (0.9098039215686274, 0.0, 0.043137254901960784),
#  (0.5450980392156862, 0.16862745098039217, 0.8862745098039215),
#  (0.6235294117647059, 0.2823529411764706, 0.0),
#  (0.9450980392156862, 0.2980392156862745, 0.7568627450980392),
#  (0.6392156862745098, 0.6392156862745098, 0.6392156862745098),
#  (1.0, 0.7686274509803922, 0.0),
#  (0.0, 0.8431372549019608, 1.0)]

# %%
d = {'Architecture': ['MobileNet-v3 Large', 'FasterNet-T1', 'shViT-s4', 'MobileNet-v3 Large', 'FasterNet-T1', 'shViT-s4'], 'F1-Score': [86.47, 85.01, 85.53, 88.29, 88.97, 87.58], 'Augmentation Procedure': ['Standard', 'Standard', 'Standard', 'On-The-Fly', 'On-The-Fly', 'On-The-Fly']}
df = pd.DataFrame(data=d)
fig, axes = plt.subplots(1,1,figsize=(7,6))
ax = sns.barplot(df, x="Architecture", y="F1-Score", hue='Augmentation Procedure', palette='bright')
for container in ax.containers:
    ax.bar_label(container)

# %%
d = {'Architecture': ['MobileNet-v3 Large', 'FasterNet-T1', 'shViT-s4', 'MobileNet-v3 Large', 'FasterNet-T1', 'shViT-s4'], 'F1-Score': [88.90, 88.31, 88.29, 90.93, 91.27, 90.98], 'Augmentation Procedure': ['Standard', 'Standard', 'Standard', 'On-The-Fly', 'On-The-Fly', 'On-The-Fly']}
df = pd.DataFrame(data=d)
fig, axes = plt.subplots(1,1,figsize=(7,6))
ax = sns.barplot(df, x="Architecture", y="F1-Score", hue='Augmentation Procedure', palette='bright')
for container in ax.containers:
    ax.bar_label(container)
